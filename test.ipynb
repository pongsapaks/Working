# %%
print("test")
for i in range(2):
    print(i, "eiei")

def test():
    print("commit 3 by us git desktop")

test()

# %%
while True:
    mail = input("Please input E-mail for creat user id:")
    if mail != "":
        break

# %%
import mysql.connector
import number
import datetime

mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database="Tasks Final"
)

def update_task_data():
  mycursor = mydb.cursor()
  Id = where_userId()
  sql = "UPDATE tasks SET email = ,TasksTiltle = ,taskType = ,taskStatus WHERE Id = {Id}"
  val = ("test@mail.com", "thisisid") # ใส่ตัวแปรตรงแถวนี้
  mycursor.execute(sql, val)
  mydb.commit()
  print(mycursor.rowcount, "record(s) affected")

def where_userId():
  mycursor = mydb.cursor()
  email = input('Please enter your email to filter')
  mycursor.execute(f'SELECT u.Id FROM users AS u WHERE u.email like "%{email}%"')
  myresult = mycursor.fetchall()
  for x in myresult:
    print(f"{x}")
where_userId()

# %%
def taskdue_input():
    taskdue = input('Please enter you Due date Example DD/MM/YYYY (15/5/2565)').split('/')
    case = datetime.datetime(int(taskdue[2]),int(taskdue[1]),int(taskdue[0]),)
    a = (case.strftime("%x"))
    print(a)
    return a
taskdue_input()

# %%
def create_at():
    x = datetime.datetime.now()
    print(x.strftime("%d/%m/%y"))
    return x.strftime("%y-%m-%d %X")
create_at()

# %%
def status_input():
    while True:
        try:
            status = input('Please select status\n0 : Inactive\n1 : active')
            if status == '1' or status == '0':
                break
            else:
                raise
        except:
            print('Invalid option')
    return status
status_input()

# %%
def status_input():
    while True:
        try:
            status = input('Please select status\n0 : Inactive\n1 : active')
            if status == '1' or status == '0':
                break
            else:
                raise
        except:
            print('Invalid option')
    return status

# %%
import mysql.connector
from number import *
import datetime

mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database="Tasks Final"
)

def create_task_data():
  mycursor = mydb.cursor()
  sql = '''INSERT INTO tasks (
    taskId,
    email,
    taskTitle,
    taskDue,
    taskType,
    created_by,
    updated_by,
    created_at,
    updated_at,
    taskStatus) 
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s,%s)'''
  val = (
      generate_tasksid(),
      email_input(),
      freetext(),
      taskdue_input(),
      1,
      'U221205125620',
      'U221205125620',
      create_at(),
      create_at(),
      '1'
      ) # ใส่ตัวแปรตรงแถวนี้
  mycursor.execute(sql, val)
  mydb.commit()
  print(mycursor.rowcount, "record inserted.")

create_task_data()

# %%
def generate_tasksid():
    x = datetime.datetime.now()
    a = 'T'+(x.strftime("%y%m%d%H%M%S"))
    print(a)
    return a
generate_tasksid()

# %%
import mysql.connector
import number
from number import *
import datetime

mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database="Tasks Final"
)

def delete_task_data():
  mycursor = mydb.cursor()
  sql = "DELETE FROM tasks WHERE taskId = %s"
  adr = ("T221205235936",) # ใส่ตัวแปรตรงแถวนี้
  print(adr)
  mycursor.execute(sql, adr)
  mydb.commit()
  print(mycursor.rowcount, "record(s) deleted")

delete_task_data()

# %%
def create_task_log():
  mycursor = mydb.cursor()
  tasks = input('Please enter your TaskId to delete')
  sql = '''INSERT INTO tasks_log (
    taskId,
    tasklogid,
    tasklogtype,
    userid,
    taskLogCreated,
    taskLogUpdated
    ) VALUES (%s, %s, %s, %s, %s, %s)'''
  val = (tasks,'2','delete',where_userId(),create_at(),create_at()) # ใส่ตัวแปรตรงแถวนี้
  mycursor.execute(sql, val)
  mydb.commit()
  print(mycursor.rowcount, "record inserted.")
create_task_log()

# %%
def where_userId():
  mycursor = mydb.cursor()
  email = input('Please enter your email: ')
  mycursor.execute(f'SELECT u.Id FROM users AS u WHERE u.email like "%{email}%"')
  myresult = mycursor.fetchall()[0]
  for x in myresult:
    print(f"{str(x)}")
    return str(x)
where_userId()

# %%
import mysql.connector
import number
from number import *
import datetime

mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database="Tasks Final"
)

def create_task_data():
  try:
    mycursor = mydb.cursor()
    sql = "INSERT INTO tasks (taskId,email,taskTitle,taskDue,taskType,created_by,updated_by,created_at,updated_at,taskStatus) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s,%s)"
    val = (generate_tasksid(),email_input(),freetext(),taskdue_input(),'1','U221205125620','U221205125620',create_at(),create_at(),'1') # ใส่ตัวแปรตรงแถวนี้
    mycursor.execute(sql, val)
    mydb.commit()
    print(mycursor.rowcount, "record inserted.")
  except:
    print("Meet something wrong Please try again")
create_task_data()

# %%
import mysql.connector
import number
from number import *
import datetime

mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database="Tasks Final"
)

def email_input():
    while True:
        try:
            mail = input("Please enter your email :")
            for i in range(len(mail)):
                if mail[i] == '@':
                    return mail
            else:
                raise
        except:
            print("That's not a valid option!")  
email_input()

# %%
x = 'mail@.com'
for i in range(len(x)):
    print(x[i])

# %%
import mysql.connector
import number
from number import *
import datetime

mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database="Tasks Final"
)
def create_task_log():
  mycursor = mydb.cursor()
  tasks = input('Please enter your TaskId to delete')
  sql = '''INSERT INTO tasks_log (
    taskId,
    tasklogid,
    tasklogtype,
    userid,
    taskLogCreated,
    taskLogUpdated
    ) VALUES (%s, %s, %s, %s, %s, %s)'''
  val = (tasks,'2','delete',where_userId(),create_at(),create_at()) # ใส่ตัวแปรตรงแถวนี้
  mycursor.execute(sql, val)
  mydb.commit()
  print(mycursor.rowcount, "record inserted.")

def where_userId():
  mycursor = mydb.cursor()
  email = input('Please enter your email: ')
  mycursor.execute(f'SELECT u.Id FROM users AS u WHERE u.email like "%{email}%"')
  myresult = mycursor.fetchall()[0]
  for x in myresult:
    x = str(x)
    print(f"{str(x)}")
    return x
where_userId()

# %%
import mysql.connector
import number
from number import *
import datetime

mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database="Tasks Final"
)

def view_task_data():
  while True:
    try:
      mycursor = mydb.cursor()
      tasktitle = input('Please enter your Tasktiltle to filter')
      email_view = input('Please enter your email to filter')
      mycursor.execute(
          f'''
          SELECT 
          taskId,taskTitle,email,taskDue 
          ,DATE_FORMAT(created_at, "%d/%m/%Y")
          ,DATE_FORMAT(updated_at, "%d/%m/%Y")
          ,(CASE
          WHEN taskStatus = 1 THEN "In-Process"
          WHEN taskStatus = 2 THEN "Approved"
          WHEN taskStatus = 3 THEN "Declined"
          WHEN taskStatus = 4 THEN "Expired"
          WHEN taskStatus = 5 THEN "Deleted"
          ELSE "-"
          END) AS status
          FROM tasks 
          WHERE taskTitle like "%{tasktitle}%" AND email like "%{email_view}%"
          '''
          )
      myresult = mycursor.fetchall()
      for i,x in enumerate (myresult):
        print(f"{i+1} {x}")
      return tasktitle,email_view
    except:
      print("Don't find any Taks")
def create_task_log():
  mycursor = mydb.cursor() #have to add any input tasksId
  sql = '''INSERT INTO tasks_log (
    taskId,
    tasklogid,
    tasklogtype,
    userid,
    taskLogCreated,
    taskLogUpdated
    ) VALUES (%s, %s, %s, %s, %s, %s)'''
  val = (f'{tasksId}','2','delete',where_userId(),create_at(),create_at()) # ใส่ตัวแปรตรงแถวนี้
  mycursor.execute(sql, val)
  mydb.commit()
  print(mycursor.rowcount, "record inserted.")

def delete_task_data():
  view_task_data()
  mycursor = mydb.cursor()
  tasksId = input('Please input your taskId to delete')
  sql = "DELETE FROM tasks WHERE taskId = %s"
  adr = (f"{tasksId}",) # ใส่ตัวแปรตรงแถวนี้
  mycursor.execute(sql, adr)
  mydb.commit()
  print(mycursor.rowcount, "record(s) deleted")
  create_task_log()
delete_task_data()

# %%
def create_task_data():
  mycursor = mydb.cursor()
  sql = "INSERT INTO tasks (taskId,email,taskTitle,taskDue,taskType,created_by,updated_by,created_at,updated_at,taskStatus) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s,%s)"
  val = (generate_tasksid(),email_input(),freetext(),taskdue_input(),'1','U221205125620','U221205125620',create_at(),create_at(),'1') # ใส่ตัวแปรตรงแถวนี้
  mycursor.execute(sql, val)
  mydb.commit()
  print(mycursor.rowcount, "record inserted.")
create_task_data()

# %%
import mysql.connector
import number
from number import *
import datetime

mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database="Tasks Final"
)
def where_userId():
  mycursor = mydb.cursor()
  email = input('Please enter your email: ')
  mycursor.execute(f'SELECT u.Id FROM users AS u WHERE u.email like "%{email}%"')
  myresult = mycursor.fetchall()[0]
  for x in myresult:
    x = str(x)
    print(f"{str(x)}")
    return x
def create_task_log():
  mycursor = mydb.cursor() #have to add any input tasksId
  tasksId = input('')
  sql = '''INSERT INTO tasks_log (
    taskId,
    tasklogid,
    tasklogtype,
    userid,
    taskLogCreated,
    taskLogUpdated
    ) VALUES (%s, %s, %s, %s, %s, %s)'''
  val = (f'{tasksId}','2','delete',where_userId(),create_at(),create_at()) # ใส่ตัวแปรตรงแถวนี้
  mycursor.execute(sql, val)
  mydb.commit()
  print(mycursor.rowcount, "record inserted.")
create_task_log()

# %%
import mysql.connector
import number
from number import *
import datetime

mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database="Tasks Final"
)
def where_userId():
  mycursor = mydb.cursor()
  email = input('Please enter your email: ')
  mycursor.execute(f'SELECT u.Id FROM users AS u WHERE u.email like "%{email}%"')
  myresult = mycursor.fetchall()
  myresult = myresult[0]
  print(myresult)
  for x in myresult:
    x = str(x)
    print(f"{str(x)}")
    return x
def create_task_log():
  mycursor = mydb.cursor() #have to add any input tasksId
  tasksId = input('')
  sql = '''INSERT INTO tasks_log (
    taskId,
    tasklogid,
    tasklogtype,
    userid,
    taskLogCreated,
    taskLogUpdated
    ) VALUES (%s, %s, %s, %s, %s, %s)'''
  val = (f'{tasksId}','2','delete',where_userId(),create_at(),create_at()) # ใส่ตัวแปรตรงแถวนี้
  mycursor.execute(sql, val)
  mydb.commit()
  print(mycursor.rowcount, "record inserted.")
create_task_log()

# %%
import mysql.connector
import number
from number import *
import datetime

mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database="Tasks Final"
)
def where_userId():
   while True:
      try:
         mycursor = mydb.cursor()
         email = input('Please enter your email: ')
         mycursor.execute(f'SELECT u.Id FROM users AS u WHERE u.email like "{email}"')
         myresult = mycursor.fetchall()
         myresult = myresult[0]
         if myresult == '':
            raise
         else:
            for x in myresult:
               x = str(x)
            return x
      except:
         print("Don't have userId, please enter it again")
where_userId()
# Out:
# 'U221205234951'

# %%
import mysql.connector
import number
from number import *
import datetime

mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database="Tasks Final"
)

def create_at():
    x = datetime.datetime.now()
    print(x.strftime("%d/%m/%y"))
    return x.strftime("%y-%m-%d %X")

def where_userId():
   while True:
      try:
         mycursor = mydb.cursor()
         email = input('Please enter your email: ')
         mycursor.execute(f'SELECT u.Id FROM users AS u WHERE u.email like "{email}"')
         myresult = mycursor.fetchall()
         myresult = myresult[0]
         if myresult == '':
            raise
         else:
            for x in myresult:
               x = str(x)
            return x
      except:
         print("Don't have userId, please enter it again")

def create_task_log():
  mycursor = mydb.cursor() #have to add any input tasksId
  tasksId = input('')
  sql = '''INSERT INTO tasks_log (
    taskId,
    tasklogid,
    tasklogtype,
    userid,
    taskLogCreated,
    taskLogUpdated
    ) VALUES (%s, %s, %s, %s, %s, %s)'''
  val = (f'{tasksId}','2','delete',where_userId(),create_at(),create_at()) # ใส่ตัวแปรตรงแถวนี้
  mycursor.execute(sql, val)
  mydb.commit()
  print(mycursor.rowcount, "record inserted.")

def delete_task_data():
  view_task_data()
  mycursor = mydb.cursor()
  tasksId = input('Please input your taskId to delete')
  sql = "DELETE FROM tasks WHERE taskId = %s"
  adr = (f"{tasksId}",) # ใส่ตัวแปรตรงแถวนี้
  mycursor.execute(sql, adr)
  mydb.commit()
  print(mycursor.rowcount, "record(s) deleted")
  create_task_log()
# Out:
# T221213132037
# That's not a valid option!
# Please choose due date today or after
# Please choose due date today or after
# 13/12/22
# 13/12/22
# 1 record inserted.

# %%
import mysql.connector
import number
from number import *
import datetime

mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database="Tasks Final"
)
def taskdue_input():# Note : เหมือนต้อง check input ที่รับเข้ามาเก็บใน database
    while True:
        try:
            taskdue = input('Please enter you Due date Example DD/MM/YYYY (15/5/2565): ').split('/')
            case = datetime.datetime(int(taskdue[2]),int(taskdue[1]),int(taskdue[0]),)
            a = (case.strftime("%x"))
            if a < datetime.date.today().strftime("%x"):
                raise
            else:
                return a
        except:
            print("Please choose due date today or after")
taskdue_input()
# Out:
# Please choose due date today or after
# Please choose due date today or after

# %%
import datetime
taskdue = input('Please enter you Due date Example DD/MM/YYYY (15/5/2565): ').split('/')
case = datetime.datetime(int(taskdue[2]),int(taskdue[1]),int(taskdue[0]),)
a = (case.strftime("%x"))
if a < datetime.date.today().strftime("%x"):
    print('No')
else:
    print('Yes')
# Out:
# Yes

# %%
print(datetime.date.today().strftime("%x"))
# Out:
# 12/13/22

# %%
def is_valid_email(email: str) -> bool:
    import re
    # Check that the email address has the correct format
    pattern = re.compile(r"^[\w\.\+-]+@[\w\.-]+\.[a-zA-Z]{2,}$")
    if not pattern.match(email):
        return False
    # Check that the email address has a valid domain
    # (Note: this is a simplified version of the check and may not be completely accurate)
    parts = email.split("@")
    if len(parts) != 2:
        return False
    domain = parts[1]
    if len(domain) < 4:
        return False
    # If all checks pass, the email address is valid
    return True
email = "po.somsakraksanti@gmail.com"
if is_valid_email(email):
    print("This is a valid email address.")
else:
    print("This is not a valid email address.")
# Out:
# This is a valid email address.

# %%
import mysql.connector
import number
from number import *
import datetime

mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database="Tasks Final"
)
def check_email_in_database(email: str, mydb) -> bool:
    # Create a cursor to execute queries
    cursor = mydb.cursor()
    
    # Execute a query to retrieve the email address from the database
    cursor.execute("SELECT email FROM users WHERE email = %s", (email,))
    
    # Fetch the results of the query
    results = cursor.fetchall()
    
    # Iterate through the results and check if the email is present
    for result in results:
        if result[0] == email:
            return True
    
    # If the email is not present, return False
    return False

def is_valid_email(email: str) -> bool:
    import re
    # Check that the email address has the correct format
    pattern = re.compile(r"^[\w\.\+-]+@[\w\.-]+\.[a-zA-Z]{2,}$")
    if not pattern.match(email):
        return False
    # Check that the email address has a valid domain
    # (Note: this is a simplified version of the check and may not be completely accurate)
    parts = email.split("@")
    if len(parts) != 2:
        return False
    domain = parts[1]
    if len(domain) < 4:
        return False
    # If all checks pass, the email address is valid
    return True
email = "dom11@gmail.com"
if is_valid_email(email) and check_email_in_database(email,mydb):
    print("This is a valid email address.")
else:
    print("This is not a valid email address.")
# Out:
# This is a valid email address.

# %%
import mysql.connector
import number
from number import *
import datetime

mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database="Tasks Final"
)
def delete_task_data():
  mycursor = mydb.cursor()
  tasksId = input('Please input your taskId to delete')
  sql = "DELETE FROM tasks WHERE taskId = %s"
  adr = (f"{tasksId}",) # ใส่ตัวแปรตรงแถวนี้
  mycursor.execute(sql, adr)
  mydb.commit()
  print(mycursor.rowcount, "record(s) deleted")
  create_task_log()

def create_task_log():
  mycursor = mydb.cursor() #have to add any input tasksId
  sql = '''INSERT INTO tasks_log (
    taskId,
    tasklogid,
    tasklogtype,
    userid,
    taskLogCreated,
    taskLogUpdated
    ) VALUES (%s, %s, %s, %s, %s, %s)'''
  val = (tasksId,'2','delete',where_userId(),create_at(),create_at()) # ใส่ตัวแปรตรงแถวนี้
  mycursor.execute(sql, val)
  mydb.commit()
  print(mycursor.rowcount, "record inserted.")

def where_userId():
   while True:
      try:
         mycursor = mydb.cursor()
         email = input('Please enter your email: ')
         mycursor.execute(f'SELECT u.Id FROM users AS u WHERE u.email like "{email}"')
         myresult = mycursor.fetchall()
         myresult = myresult[0]
         if myresult == '':
            raise
         else:
            for x in myresult:
               x = str(x)
            return x
      except:
         print("Don't have userId, please enter it again")

def create_at():
    x = datetime.datetime.now()
    print(x.strftime("%d/%m/%y"))
    return x.strftime("%y-%m-%d %X")

# %%
import mysql.connector
import datetime

mydb = mysql.connector.connect(
        host="localhost",
        port="3500",
        user="root",
        password="admin",
        database="Tasks Final"
    )
def view_task_data():
  while True:
    try:
      mycursor = mydb.cursor()
      tasktitle = input('Please enter your Tasktiltle to filter')
      email_view = input('Please enter your email to filter')
      mycursor.execute(
          f'''
          SELECT 
          taskId,taskTitle,email,taskDue 
          ,DATE_FORMAT(created_at, "%d/%m/%Y")
          ,DATE_FORMAT(updated_at, "%d/%m/%Y")
          ,(CASE
          WHEN taskStatus = 1 THEN "In-Process"
          WHEN taskStatus = 2 THEN "Approved"
          WHEN taskStatus = 3 THEN "Declined"
          WHEN taskStatus = 4 THEN "Expired"
          WHEN taskStatus = 5 THEN "Deleted"
          ELSE "-"
          END) AS status
          FROM tasks 
          WHERE taskTitle like "%{tasktitle}%" AND email like "%{email_view}%"
          '''
          )
      myresult = mycursor.fetchall()
      for i,x in enumerate (myresult):
        print(f"{i+1} {x}")
      return tasktitle,email_view
    except:
      print("Don't find any Taks")
      
def delete_task_data():
    view_task_data()
    # Prompt the user for a task ID until a valid one is entered
    while True:
        try:
            # Prompt the user for a task ID
            tasks_id = input("Please input your task ID to delete: ")

            # Validate the task ID
            if not tasks_id:
                raise ValueError("Task ID cannot be empty")

            # Check if the task ID exists in the database
            mycursor = mydb.cursor()
            mycursor.execute(f"SELECT * FROM tasks WHERE taskId = '{tasks_id}'")
            result = mycursor.fetchone()
            if not result:
                raise ValueError("Task ID does not exist in the database")

            # If the task ID is valid, delete the task from the database
            sql = "DELETE FROM tasks WHERE taskId = %s"
            adr = (tasks_id,)
            mycursor.execute(sql, adr)
            mydb.commit()
            print(f"{mycursor.rowcount} record(s) deleted")

            # Create a log entry for the deleted task
            create_task_log(tasks_id)

            # Exit the loop
            break
        except ValueError as e:
            # If the task ID is invalid, print an error message and try again
            print(e)


def create_task_log(tasks_id):
    # Prompt the user for their email
    user_id = get_user_id(user_email)

    # Insert a log entry for the deleted task
    mycursor = mydb.cursor()
    sql = '''
        INSERT INTO tasks_log (
            taskId,
            tasklogid,
            tasklogtype,
            userid,
            taskLogCreated,
            taskLogUpdated
        ) VALUES (%s, %s, %s, %s, %s, %s)
    '''
    val = (tasks_id, '2', 'delete', user_id, get_current_time(), get_current_time())
    mycursor.execute(sql, val)
    mydb.commit()
    print(f"{mycursor.rowcount} record inserted.")

def get_user_id(email):
    # Connect to the database
    mydb = mysql.connector.connect(
        host="localhost",
        port="3500",
        user="root",
        password="admin",
        database="Tasks Final"
    )

    # Query the database for the user ID
    mycursor = mydb.cursor()
    mycursor.execute(f'SELECT u.Id FROM users AS u WHERE u.email like "{email}"')
    myresult = mycursor.fetchall()

    # Return the user ID, or None if it was not found
    if myresult:
        return myresult[0][0]
    return None

def get_current_time():
    # Get the current time
    x = datetime.datetime.now()
    return x.strftime("%Y-%m-%d %X")

user_email = input('Please input your email to login')
delete_task_data()
# Out:
# 1 ('T221213125315', 'test', 'dom11@gmail.com', '12/16/65', '13/12/2022', '13/12/2022', 'In-Process')
# 1 record(s) deleted
# 1 record inserted.

# %%
user_email = 'dom11@gmail.com'
def update_task_data(user_email):
    # Connect to the database
    mydb = mysql.connector.connect(
        host="localhost",
        port="3500",
        user="root",
        password="admin",
        database="Tasks Final"
    )

    # Prompt the user for a task ID until a valid one is entered
    while True:
        try:
            # Prompt the user for the task ID
            task_id = input("Please input the task ID to update: ")

            # Validate the task ID
            if not task_id:
                raise ValueError("Task ID cannot be empty")

            # Check if the task ID exists in the database
            mycursor = mydb.cursor()
            mycursor.execute(f"SELECT * FROM tasks WHERE taskId = '{task_id}'")
            result = mycursor.fetchone()
            if not result:
                raise ValueError("Task ID does not exist in the database")

            # If the task ID is valid, prompt the user for the new values for the fields
            tasks_title = input("Please enter the new task title: ")
            task_status = input("Please enter the new task status: ")

            # Update the task in the database
            sql = "UPDATE tasks SET email = %s, TasksTiltle = %s, taskStatus = %s WHERE Id = %s"
            val = (user_email, tasks_title, task_status, task_id)
            mycursor.execute(sql, val)
            mydb.commit()
            print(f"{mycursor.rowcount} record(s) affected")

            # Exit the loop
            break

        # Handle invalid input
        except ValueError as error:
            print(error)
update_task_data(user_email)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In [18], line 46
#      44         except ValueError as error:
#      45             print(error)
# ---> 46 update_task_data(user_email)
#
# Cell In [18], line 36, in update_task_data(user_email)
#      34 sql = "UPDATE tasks SET email = %s, TasksTiltle = %s, taskStatus = %s WHERE Id = %s"
#      35 val = (user_email, tasks_title, task_status, task_id)
# ---> 36 mycursor.execute(sql, val)
#      37 mydb.commit()
#      38 print(f"{mycursor.rowcount} record(s) affected")
#
# File /Volumes/hd2/pb2/build/sb_0-8365893-1662636246.23/build/root/Library/Python/3.9/install.tmp/lib/python3.9/site-packages/mysql/connector/cursor.py:564, in execute(self, operation, params, multi)
#
# ...

# %%
def delete_user_data():
  mydb = mysql.connector.connect(
        host="localhost",
        port="3500",
        user="root",
        password="admin",
        database="Tasks Final"
    )
  try:
    email_in = email_check_in()
    mycursor = mydb.cursor()
    sql = "UPDATE users SET status = '9' WHERE email = %s"
    val = (email_in)
    mycursor.execute(sql,val)
    mydb.commit()
    print(mycursor.rowcount, "record(s) deleted")
    if mycursor.rowcount == 0:
      raise
  except:
      print("The email is not exist.\n")
def email_check_in():
    mydb = mysql.connector.connect(
        host="localhost",
        port="3500",
        user="root",
        password="admin",
        database="Tasks Final"
    )
    while True:
        try:
            email_in = email_input()
            mycursor = mydb.cursor()
            mycursor.execute(f'SELECT u.email FROM users AS u WHERE u.email like "%{email_in}%"')
            myresult = mycursor.fetchall()
            if len (myresult) != 0:
                print(f'{email_in}')
                return email_in
            else:
                raise
        except:
            print("Invalid email, try again.\n")
delete_user_data()
# Out:
# Invalid email, try again.
#
# Invalid email, try again.

# %%
import mysql.connector
mydb = mysql.connector.connect(
            host="localhost",
            port="3500",
            user="root",
            password="admin",
            database="Tasks Final"
        )

def get_user_id(email):
    # Connect to the database
    mydb = mysql.connector.connect(
        host="localhost",
        port="3500",
        user="root",
        password="admin",
        database="Tasks Final"
    )

    # Query the database for the user ID
    mycursor = mydb.cursor()
    mycursor.execute(f'SELECT u.Id FROM users AS u WHERE u.email like "{email}"')
    myresult = mycursor.fetchall()

    # Return the user ID, or None if it was not found
    if myresult:
        return myresult[0][0]
    return None
def delete_user_data():
    while True:
        try:
            email_in = input("Enter the email of the user to delete: ")
            id = get_user_id(email_in)
            cursor = mydb.cursor()
            # Update the status of the user with the given email to '9'
            sql = f"UPDATE users SET status = '9' WHERE Id = {id}"
            cursor.execute(sql)
            mydb.commit()
            print(cursor.rowcount, "record(s) deleted")
        except mysql.connector.Error as err:
            # Print any error messages
            print(f'An error occurred: {err}')
delete_user_data()
# Out:
# An error occurred: 1054 (42S22): Unknown column 'None' in 'where clause'

# %%
import mysql.connector
import datetime
mydb = mysql.connector.connect(
        host="localhost",
        port="3500",
        user="root",
        password="admin",
        database="Tasks Final"
    )
user_email = 'dom11@gmail.com'

def create_at_datetime():
    x = datetime.datetime.now()
    return x.strftime('%Y-%m-%d %H:%M:%S')

def get_user_id(email):
    # Connect to the database
    mydb = mysql.connector.connect(
        host="localhost",
        port="3500",
        user="root",
        password="admin",
        database="Tasks Final"
    )

    # Query the database for the user ID
    mycursor = mydb.cursor()
    mycursor.execute(f'SELECT u.Id FROM users AS u WHERE u.email like "{email}"')
    myresult = mycursor.fetchall()

    # Return the user ID, or None if it was not found
    if myresult:
        return myresult[0][0]
    return None

def update_task_data(user_email):
  while True:
    try:
      tasks_id = input("Please input your task ID to Update: ")
      if not tasks_id:
        raise ValueError("Task ID cannot be empty")
      mycursor = mydb.cursor()
      mycursor.execute(f"SELECT * FROM tasks WHERE taskId = '{tasks_id}'")
      result = mycursor.fetchone()
      if not result:
        raise ValueError("Task ID does not exist in the database")
      tasktitle = input("Please input your tasktitle to Update: ")
      taskstatus = input('''1 = "In-Process"\n2 = "Approved"\n3 = "Declined"\n4 = "Expired"\n5 = "Deleted"\nPlease input your taskstatus to Update: ''')
      if taskstatus not in ['1', '2', '3', '4', '5']:
        raise ValueError("Task status is not true")
      mycursor = mydb.cursor()
      sql = "UPDATE tasks SET taskTitle = %s,updated_by = %s, updated_at = %s ,taskStatus = %s WHERE taskId = %s"
      val = (tasktitle,get_user_id(user_email),create_at_datetime(),taskstatus,tasks_id)
      mycursor.execute(sql, val)
      mydb.commit()
      print(mycursor.rowcount, "record(s) affected")
      break
    except ValueError as e:
       print(e)
update_task_data(user_email)
# Out:
# 1 record(s) affected

# %%
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database='Tasks Final'
)

def view_task_data():
  while True:
    try:
      mycursor = mydb.cursor()
      mycursor.execute(
          f'''
          SELECT 
          taskId,taskTitle,email,taskDue 
          ,DATE_FORMAT(created_at, "%d/%m/%Y")
          ,DATE_FORMAT(updated_at, "%d/%m/%Y")
          ,(CASE
          WHEN taskStatus = 1 THEN "In-Process"
          WHEN taskStatus = 2 THEN "Approved"
          WHEN taskStatus = 3 THEN "Declined"
          WHEN taskStatus = 4 THEN "Expired"
          WHEN taskStatus = 5 THEN "Deleted"
          ELSE "-"
          END) AS status
          FROM tasks 
          '''
          )
      myresult = mycursor.fetchall()
      for i,x in enumerate (myresult):
        print(f"{i+1} {x}")
      return tasktitle,email_view
    except:
      print("Don't find any Taks")

def get_task_data():
  data = []
  mycursor = mydb.cursor()
  mycursor.execute(
      f'''
      SELECT 
      taskId,taskTitle,email,taskDue 
      ,DATE_FORMAT(created_at, "%d/%m/%Y")
      ,DATE_FORMAT(updated_at, "%d/%m/%Y")
      ,(CASE
      WHEN taskStatus = 1 THEN "In-Process"
      WHEN taskStatus = 2 THEN "Approved"
      WHEN taskStatus = 3 THEN "Declined"
      WHEN taskStatus = 4 THEN "Expired"
      WHEN taskStatus = 5 THEN "Deleted"
      ELSE "-"
      END) AS status
      FROM tasks 
      '''
      )
  myresult = mycursor.fetchall()
  for row in myresult:
    data.append(row)
  df = pd.DataFrame(data, columns=['taskId', 'taskTitle', 'email', 'taskDue', 'created_at', 'updated_at', 'status'])
  return df

def plot_task_status():
  df = get_task_data()
  # Countplot of task statuses
  plt.figure(figsize=(10,5))
  sns.countplot(x='status', data=df)
  plt.title('Task Status Counts')
  plt.xlabel('Status')
  plt.ylabel('Count')
  plt.show()

def plot_task_create():
  df = get_task_data()
  # Bar chart of task creation dates
  plt.figure(figsize=(10,5))
  df['created_at'] = pd.to_datetime(df['created_at'])
  df.groupby(df['created_at'].dt.date).count()['taskId'].plot(kind='bar')
  plt.title('Task Creation Dates')
  plt.xlabel('Date')
  plt.ylabel('Count')
  plt.show()

def plot_task_duedate():
  df = get_task_data()
  # Scatterplot of task due dates vs. creation dates
  plt.figure(figsize=(10,5))
  df['taskDue'] = pd.to_datetime(df['taskDue'])
  plt.scatter(x=df['created_at'], y=df['taskDue'])
  plt.title('Task Due Dates vs. Creation Dates')
  plt.xlabel('Creation Date')
  plt.ylabel('Due Date')
  plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d/%m/%Y'))
  plt.show()

plot_task_status()
# Out:
# /Users/pongsapak/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '16/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /Users/pongsapak/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '18/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /Users/pongsapak/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '19/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
def taskdue_input():
  while True:
    try:
      taskdue = input('Please enter you Due date Example DD/MM/YYYY (15/5/2022): ').split('/')
      case = datetime.datetime(int(taskdue[2]), int(taskdue[1]), int(taskdue[0]))
      if case < datetime.datetime.now():
        raise
      else:
        return case.strftime("%x")
    except:
      print("Please choose due date today or after")

taskdue_input()
# Out:
# Please choose due date today or after
# Please choose due date today or after
# Please choose due date today or after

# %%
import mysql.connector
mydb = mysql.connector.connect(
        host="localhost",
        port="3500",
        user="root",
        password="admin",
        database='Tasks Final'
    )
db1 = 'Tasks Final'

def get_user_id(email):
    mydb = mysql.connector.connect(
        host="localhost",
        port="3500",
        user="root",
        password="admin",
        database='Tasks Final'
    )
    mycursor = mydb.cursor()
    mycursor.execute(
        f'SELECT u.Id FROM users AS u WHERE u.email like "{email}"')
    myresult = mycursor.fetchall()
    if myresult:
        return myresult[0][0]
    return None
def check_email_in_database(email: str, mydb) -> bool:
    cursor = mydb.cursor()
    cursor.execute("SELECT email FROM users WHERE email = %s", (email,))
    results = cursor.fetchall()
    for result in results:
        if result[0] == email:
            return True
    return False

def is_valid_email(email: str) -> bool:
    import re
    pattern = re.compile(r"^[\w\.\+-]+@[\w\.-]+\.[a-zA-Z]{2,}$")
    if not pattern.match(email):
        return False
    parts = email.split("@")
    if len(parts) != 2:
        return False
    domain = parts[1]
    if len(domain) < 4:
        return False
    return True

def delete_user_data(db1):
    # Connect to the database
    mydb = mysql.connector.connect(
        host="localhost",
        port="3500",
        user="root",
        password="admin",
        database=db1
    )

    # Get the email address to delete
    try:
        email_in = input('Please enter your email to filter :')
    if is_valid_email(email_in) and check_email_in_database(email_in, mydb):
        pass
    else:
        raise
    # Create a cursor and execute the UPDATE query
    mycursor = mydb.cursor()
    sql = "UPDATE users As u SET u.status = '0' WHERE u.Id = %s"
    print(email_in)
    val = (get_user_id(email_in),)
    print(val)
    mycursor.execute(sql, val)
    mydb.commit()

    # Print the number of rows affected by the UPDATE query
    print(mycursor.rowcount, "record(s) deleted")
    if mycursor.rowcount == 0:
        print("The email is not exist.\n")

delete_user_data(db1)
# Out:
# dom11@gmail.com
# ('U221205234951',)
# 1 record(s) deleted

# %%
import mysql.connector
mydb = mysql.connector.connect(
        host="localhost",
        port="3500",
        user="root",
        password="admin",
        database='Tasks Final'
    )
db1 = 'Tasks Final'
user_email = 'dom11@gmail.com'
def create_at():
    x = datetime.datetime.now()
    print(x.strftime("%d/%m/%y"))
    return x.strftime("%y-%m-%d %X")
def create_at_datetime():
    x = datetime.datetime.now()
    return x.strftime('%Y-%m-%d %H:%M:%S')
def create_updatetask_log_(tasks_id, user_email,taskstatus):
    # Prompt the user for their email
    user_id = get_user_id(user_email)
    if taskstatus == 1:
       taskstaus_name = 'In-Process'
    elif taskstatus == 2:
       taskstaus_name = 'approve'
    elif taskstatus == 3:
       taskstaus_name = 'Declined'
    elif taskstatus == 4:
       taskstaus_name = 'Expired'
    elif taskstatus == 5:
       taskstaus_name = 'Deleted'
    # Insert a log entry for the deleted task
    mycursor = mydb.cursor()
    sql = '''
        INSERT INTO tasks_log (
            taskId,
            tasklogid,
            tasklogtype,
            userid,
            taskLogCreated,
            taskLogUpdated
        ) VALUES (%s, %s, %s, %s, %s, %s)
    '''
    val = (tasks_id, taskstatus, 'delete', user_id, create_at(), create_at())
    mycursor.execute(sql, val)
    mydb.commit()
    print(f"{mycursor.rowcount} record inserted.")
def update_task_data(user_email,db1):
  mydb = mysql.connector.connect(
  host="localhost",
  port = "3500",
  user="root",
  password="admin",
  database=db1
)
  while True:
    try:
      tasks_id = input("Please input your task ID to Update: ")
      if not tasks_id:
        raise ValueError("Task ID cannot be empty")
      mycursor = mydb.cursor()
      mycursor.execute(f"SELECT * FROM tasks WHERE taskId = '{tasks_id}'")
      result = mycursor.fetchone()
      if not result:
        raise ValueError("Task ID does not exist in the database")
      tasktitle = input("Please input your tasktitle to Update: ")
      taskstatus = input('''1 = "In-Process"\n2 = "Approved"\n3 = "Declined"\n4 = "Expired"\n5 = "Deleted"\nPlease input your taskstatus to Update: ''')
      if taskstatus not in ['1', '2', '3', '4', '5']:
        raise ValueError("Task status is not true")
      mycursor = mydb.cursor()
      sql = "UPDATE tasks SET taskTitle = %s,updated_by = %s, updated_at = %s ,taskStatus = %s WHERE taskId = %s"
      val = (tasktitle,get_user_id(user_email),create_at_datetime(),taskstatus,tasks_id)
      mycursor.execute(sql, val)
      mydb.commit()
      print(mycursor.rowcount, "record(s) affected")
      create_updatetask_log_(tasks_id,user_email,taskstatus)
      break
    except ValueError as e:
       print(e)
update_task_data(user_email,db1)
# Out:
# 1 record(s) affected
# 24/12/22
# 24/12/22
# 1 record inserted.

# %%
import mysql.connector
mydb = mysql.connector.connect(
        host="localhost",
        port="3500",
        user="root",
        password="admin",
        database='Tasks Final'
    )
db1 = 'Tasks Final'
user_email = 'dom11@gmail.com'
def create_at():
    x = datetime.datetime.now()
    print(x.strftime("%d/%m/%y"))
    return x.strftime("%y-%m-%d %X")

def get_user_id(email):
    mydb = mysql.connector.connect(
        host="localhost",
        port="3500",
        user="root",
        password="admin",
        database='Tasks Final'
    )
    mycursor = mydb.cursor()
    mycursor.execute(
        f'SELECT u.Id FROM users AS u WHERE u.email like "{email}"')
    myresult = mycursor.fetchall()
    if myresult:
        return myresult[0][0]
    return None

def taskdue_input():
  while True:
    try:
      taskdue = input('Please enter you Due date Example DD/MM/YYYY (15/5/2022): ').split('/')
      case = datetime.datetime(int(taskdue[2]), int(taskdue[1]), int(taskdue[0]))
      if case < datetime.datetime.now():
        raise
      else:
        return case.strftime("%x")
    except:
      print("Please choose due date today or after")


def freetext():
    x = input('Please enter Tasktile: ')
    return x

def email_input():
    while True:
        try:
            mail = input("Please enter your email :")
            for i in range(len(mail)):
                if mail[i] == '@':
                    return mail
            else:
                raise
        except:
            print("That's not a valid option!")

def generate_tasksid():
    x = datetime.datetime.now()
    a = 'T'+(x.strftime("%y%m%d%H%M%S"))
    print(a)
    return a

def create_createtask_log(tasks_id, user_email):
    # Prompt the user for their email
    user_id = get_user_id(user_email)

    # Insert a log entry for the deleted task
    mycursor = mydb.cursor()
    sql = '''
        INSERT INTO tasks_log (
            taskId,
            tasklogid,
            tasklogtype,
            userid,
            taskLogCreated,
            taskLogUpdated
        ) VALUES (%s, %s, %s, %s, %s, %s)
    '''
    val = (tasks_id, '1', 'create', user_id, create_at(), create_at())
    mycursor.execute(sql, val)
    mydb.commit()
    print(f"{mycursor.rowcount} record inserted Task Log.")

def create_task_data(user_email,db1):
    mydb = mysql.connector.connect(
    host="localhost",
    port = "3500",
    user="root",
    password="admin",
    database=db1
    )
    a = generate_tasksid()
    mycursor = mydb.cursor()
    sql = "INSERT INTO tasks (taskId,email,taskTitle,taskDue,taskType,created_by,updated_by,created_at,updated_at,taskStatus) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s,%s)"
    val = (a,email_input(),freetext(),taskdue_input(),'1',get_user_id(user_email),get_user_id(user_email),create_at(),create_at(),'1') # ใส่ตัวแปรตรงแถวนี้
    mycursor.execute(sql, val)
    mydb.commit()
    print(mycursor.rowcount, "record inserted.")
    log('tasks log.txt', val)
    create_createtask_log(a, user_email)
create_task_data(user_email,db1)
# Out:
# T221224154201
# 24/12/22
# 24/12/22
# 1 record inserted.
# 24/12/22
# 24/12/22
# 1 record inserted Task Log.
